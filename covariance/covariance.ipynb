# %%
import numpy as np

# %%
def calculate_covariance_matrix(vectors: list[list[float]]) -> list[list[float]]:
    
    vec_size = len(vectors)
    cov_mat = np.zeros((vec_size, vec_size))
    
    def cov(x, y):
        x_mean = np.mean(x)
        y_mean =  np.mean(y)
        c = np.sum((x - x_mean) * (y - y_mean)) / (len(x) - 1)
        return c
        
    for i in range(vec_size):
        for j in range(vec_size):
            cov_mat[i][j] = cov(vectors[i] , vectors[j])
    return cov_mat

# %%
x_in = np.array([[1, 2, 3], [4, 5, 6]])

# %%
cor = calculate_covariance_matrix(x_in)
cor
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
x = x_in[0]
x

# %%
y = x_in[1]
y

# %%
x_mean = np.mean(x)
y_mean =  np.mean(y)

# %%
(x - x_mean) * (y - y_mean)

# %%
np.sum((x - x_mean) * (y - y_mean)) / (3 - 1)

# %%
def cov(x, y):
    x_mean = np.mean(x)
    y_mean =  np.mean(y)
    c = np.sum((x - x_mean) * (y - y_mean)) / (len(x) - 1)
    return c

# %%
x_in.shape

# %%
cov_mat = np.zeros((x_in.shape[0], x_in.shape[0]))
cov_mat

# %%
for i in range(x_in.shape[0]):
    for j in range(x_in.shape[0]):
        cov_mat[i][j] = cov(x_in[i] , x_in[j])

# %%
cov_mat
