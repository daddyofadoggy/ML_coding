# %%
# !PWD
# Out:
# /Users/ron/Documents/github/ML_coding/linear_regression

# %%
# !wget https://raw.githubusercontent.com/campusx-official/linear-regression-assumptions/refs/heads/main/linear-regression-assumptions.ipynb
# Out:
# --2025-08-22 10:37:01--  https://raw.githubusercontent.com/campusx-official/linear-regression-assumptions/refs/heads/main/linear-regression-assumptions.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8003::154, 2606:50c0:8000::154, 2606:50c0:8002::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8003::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 119663 (117K) [text/plain]
# Saving to: ‘linear-regression-assumptions.ipynb’
#
# linear-regression-a 100%[===================>] 116.86K  --.-KB/s    in 0.05s
#
# 2025-08-22 10:37:01 (2.49 MB/s) - ‘linear-regression-assumptions.ipynb’ saved [119663/119663]

# %%
# !wget https://raw.githubusercontent.com/campusx-official/linear-regression-assumptions/refs/heads/main/data.csv
# Out:
# --2025-08-22 10:39:22--  https://raw.githubusercontent.com/campusx-official/linear-regression-assumptions/refs/heads/main/data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8003::154, 2606:50c0:8000::154, 2606:50c0:8002::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8003::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15761 (15K) [text/plain]
# Saving to: ‘data.csv’
#
# data.csv            100%[===================>]  15.39K  --.-KB/s    in 0.02s
#
# 2025-08-22 10:39:22 (664 KB/s) - ‘data.csv’ saved [15761/15761]
